# %%
import pandas as pd
import json

# %%
df = pd.read_csv("E:\ML-Projects\heart-data\healthcare-dataset-stroke-data.csv")

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
Data = df.to_dict(orient='records')

# %%
file_path = r'E:\ML-Projects\data.json'

# %%
# Save dictionary to a JSON file
with open(file_path, 'w') as file:
    json.dump(Data, file)

print(f"Data has been saved to {file_path}")
# Out:
# Data has been saved to E:\ML-Projects\data.json

# %%
Data
# Out:
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.69,
#   'bmi': 36.6,
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': 0,
#   'heart_disease': 0,
#   'ever_married': 'Yes',
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': nan,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 105.92,
#   'bmi': 32.5,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': 0,
#   'heart_disease': 0,
# ...

# %%
import pymongo

DATABASE_NAME = 'ineuron'

CONNECTION_URL = 'mongodb+srv://sameerup1996:SameerAli123@cluster1.v0t46wx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1'

client = pymongo.MongoClient(CONNECTION_URL)


database = client[DATABASE_NAME]

COLLECTION_NAME = 'heart_stroke'
collection = database[COLLECTION_NAME]

rec = collection.insert_many(Data)
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('66856ffc1bad4bae5db66d06'), 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# 1: {'_id': ObjectId('66856ffc1bad4bae5db66d07'), 'id': 51676, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 202.21, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# 2: {'_id': ObjectId('66856ffc1bad4bae5db66d08'), 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1}
# ...
